# %% [markdown]
# **Read Salary dataset and generate sequential ids.
# Some of the records contain DOLLAR as prefix and some not. Please make all records with ‘DOLLAR’ prefix.**

# %% [markdown]
# **IMPORT LIBRARY**

# %%
import pandas as pd

# %% [markdown]
# **READING CSV FILE**

# %%
path = "/content/SalaryInfo.csv"

# %%
df = pd.read_csv(path)

# %% [markdown]
# **SHOWING DATA**

# %%
df.head(18)
# Out:
#    PayBand Average Salary Pay Band Minimum Pay Band Maximum      Range
# 0        B      $19112.82        $19090.00        $23884.00   $4794.00
# 1        C       19838.75        $19090.00            25268   $6178.00
# 2        D       19838.75        $19090.00            25268   $8151.00
# 3        E       19838.75        $19090.00            25268  $10877.00
# 4        F      $25466.47            19778            25268  $13185.00
# 5        G      $28698.90            19778            25268  $14504.00
# 6        H      $30294.24            19778            25268  $15954.00
# 7        I      $31513.33        $26502.00            25268  $17668.00
# 8        J        35119.4        $29136.00            25268  $19424.00
# 9        K        35119.4        $31848.00            25268  $21232.00
# 10       L        35119.4        $35032.00        $58387.00  $23355.00
# 11       M        35119.4        $38885.00        $64808.00  $25923.00
# ...

# %%
data.head().loc[0]['Average Salary'] = '19112.82'

# %% [markdown]
# **APPENDING $ PREFIX TO EVERY COLUMN VALUE**

# %%
for i in range(len(data)):
  if data.loc[i]['Average Salary'][0] != '$':
    data.loc[i]['Average Salary'] = "${}".format(data.loc[i]['Average Salary'])
  if data.loc[i]['Pay Band Minimum'][0] != '$':
    data.loc[i]['Pay Band Minimum'] = "${}".format(data.loc[i]['Pay Band Minimum'])
  if data.loc[i]['Pay Band Maximum'][0] != '$':
    data.loc[i]['Pay Band Maximum'] = "${}".format(data.loc[i]['Pay Band Maximum'])
  if data.loc[i]['Range'][0] != '$':
    data.loc[i]['Range'] = "${}".format(data.loc[i]['Range'])

# %% [markdown]
# **PRESENTING UPDATED DATA**

# %%
data
# Out:
#    PayBand Average Salary Pay Band Minimum Pay Band Maximum      Range
# 0        B      $19112.82        $19090.00        $23884.00   $4794.00
# 1        C      $19838.75        $19090.00           $25268   $6178.00
# 2        D      $19838.75        $19090.00           $25268   $8151.00
# 3        E      $19838.75        $19090.00           $25268  $10877.00
# 4        F      $25466.47           $19778           $25268  $13185.00
# 5        G      $28698.90           $19778           $25268  $14504.00
# 6        H      $30294.24           $19778           $25268  $15954.00
# 7        I      $31513.33        $26502.00           $25268  $17668.00
# 8        J       $35119.4        $29136.00           $25268  $19424.00
# 9        K       $35119.4        $31848.00           $25268  $21232.00
# 10       L       $35119.4        $35032.00        $58387.00  $23355.00
# 11       M       $35119.4        $38885.00        $64808.00  $25923.00
# ...
